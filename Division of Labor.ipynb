# %%
import os

# %%
f = open("sf_restaurant_names.txt","r")
out = open("actually_john.txt", "w+")

# %%
for index, line in enumerate(f):
    if index <= 4485 and index > 3485:
        print(str(line))
        out.write(str(line))
# Out:
# schuberts-bakery-san-francisco
#
# pressed-juicery-san-francisco-6
#
# allegro-romano-san-francisco
#
# tropisueño-san-francisco-3
#
# tabu-lounge-san-francisco
#
# wallys-fried-chicken-san-francisco
#
# gateaux-san-francisco
#
# two-jacks-seafood-san-francisco-3
#
# one-market-plaza-san-francisco
#
# showplace-triangle-plaza-san-francisco
#
# ushi-taro-san-francisco
#
# comfort-women-memorial-san-francisco
#
# castro-tarts-san-francisco
#
# piece-of-heaven-san-francisco
#
# executive-cafe-san-francisco
#
# ben-thai-cafe-san-francisco
#
# pho-nice-vietnamese-restaurant-san-francisco-2
#
# pilsner-inn-san-francisco
#
# gateway-express-san-francisco-2
#
# mixt-san-francisco-2
#
# blue-bottle-coffee-san-francisco-14
#
# jiangnan-cuisine-san-francisco
#
# mathilde-french-bistro-san-francisco
#
# cafe-madeleine-san-francisco-2
#
# las-cocineras-restaurant-san-francisco
#
# the-peace-pagoda-san-francisco-2
#
# third-rail-san-francisco
#
# the-willows-san-francisco
#
# ...

# %%
max(indexes)
# Out:
# 6485
